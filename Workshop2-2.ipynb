# %%
import re
import pandas as pd
import numpy as np
from datetime import datetime

# %%
airbnb = pd.read_csv('airbnb_v1.csv',skiprows=1,dtype='str')
airbnb = airbnb.drop('Unnamed: 15', axis=1)
airbnb
# Out:
#              id                                               name host   id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 39113  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 39114  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 39115  36485431            Sunny Studio at Historical Neighborhood  23492952
# 39116  36485609               43rd St. Time Square-cozy single bed  30985759
# 39117  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#          [host_name]     neighbourhood group  \
# 0               John  Brooklyn - **Borough**
# 1           Jennifer               Manhattan
# 2          Elisabeth               Manhattan
# 3        LisaRoxanne                Brooklyn
# 4              Laura               Manhattan
# ...              ...                     ...
# 39113        Sabrina                Brooklyn
# 39114        Marisol                Brooklyn
# 39115  Ilgar & Aysel               Manhattan
# 39116            Taz               Manhattan
# 39117     Christophe               Manhattan
#
#                                            neighbourhood   latitude  \
# 0      KensingtonBrooklyn - **Borough**-Brooklyn - **...   40.64749
# 1                                                Midtown   40.75362
# 2                                                 Harlem  40.80902N
# 3                                           Clinton Hill  40.68514N
# 4                                            East Harlem   40.79851
# ...                                                  ...        ...
# 39113                                 Bedford-Stuyvesant   40.67853
# 39114                                           Bushwick   40.70184
# 39115                                             Harlem   40.81475
# 39116                                     Hell's Kitchen   40.75751
# 39117                                     Hell's Kitchen   40.76404
#
#           longitude    room and type minimum nights number of reviews (total)  \
# 0         -73.97237     Private room              1                         9
# 1         -73.98377  Entire home/apt              1                        45
# 2          -73.9419     Private room              3                         0
# 3         -73.95976  Entire home/apt              1                       270
# 4         -73.94399  Entire home/apt             10                         9
# ...             ...              ...            ...                       ...
# 39113     -73.94995     Private room              2                         0
# 39114  -73.93317° W     Private room              4                         0
# 39115     -73.94867  Entire home/apt             10                         0
# 39116     -73.99112      Shared room              1                         0
# 39117     -73.98933     Private room              7                         0
#
#       last review (date) reviews per month        floor           noise.dB.  \
# 0             2018-10-19              0.21  First Floor  69.0564645654522dB
# 1             2019-05-21              0.38  First Floor  56.0542782840785dB
# 2                    NaN               NaN  First Floor  56.0542782840785dB
# 3             2019-07-05              4.64  First Floor  69.0564645654522dB
# 4             2018-11-19               0.1  First Floor         56.05427828
# ...                  ...               ...          ...                 ...
# 39113                NaN               NaN  First Floor  69.0564645654522dB
# 39114                NaN               NaN  First Floor  69.0564645654522dB
# 39115                NaN               NaN  First Floor  56.0542782840785dB
# 39116                NaN               NaN  First Floor  56.0542782840785dB
# 39117                NaN               NaN  First Floor  56.0542782840785dB
#
#       price
# 0       149
# 1      $225
# 2       150
# 3        89
# 4        80
# ...     ...
# 39113    70
# 39114    40
# 39115   115
# 39116    55
# 39117    90
#
# [39118 rows x 16 columns]

# %% [markdown]
# ## Numerical Columns

# %%
#airbnb['reviews per month'].unique()

# %%
## ID
airbnb['id'] = [re.sub('[^0-9]','',str(x)) for x in airbnb['id']]
airbnb['id'] = airbnb['id'].astype(int)

## HOST ID
airbnb['host   id'] = [re.sub('[^0-9]','',str(x)) for x in airbnb['host   id']]
airbnb['host   id'] = airbnb['host   id'].astype(int)

## MINIMUM NIGHTS
airbnb['minimum nights'] = [re.sub('[^0-9]','',str(x)) for x in airbnb['minimum nights']]
airbnb['minimum nights'] = airbnb['minimum nights'].astype(int)

## NUMBER OF REVIEWS
airbnb['number of reviews (total)'] = [re.sub('[^0-9]','',str(x)) for x in airbnb['number of reviews (total)']]
airbnb['number of reviews (total)'] = airbnb['number of reviews (total)'].astype(int)

## REVIEWS PER MONTH
airbnb['reviews per month'] = [re.sub('nan|NaN','0',str(x)) for x in airbnb['reviews per month']]
airbnb['reviews per month'] = [re.sub(r'[^\d.]|(?<=\.)\..*','',str(x)) for x in airbnb['reviews per month']]
airbnb['reviews per month'] = airbnb['reviews per month'].astype(float) #'[^0-9.]'

## NOISE
airbnb['noise.dB.'] = [re.sub('[^0-9.]','',str(x)) for x in airbnb['noise.dB.']]
airbnb['noise.dB.'] = airbnb['noise.dB.'].astype(float)

## PRICE
airbnb['price'] = [re.sub('[^0-9.]','',str(x)) for x in airbnb['price']]
airbnb['price'] = airbnb['price'].astype(int)

## LATITUDE
airbnb['latitude'] = [re.sub('[^0-9.]','',str(x)) for x in airbnb['latitude']]
airbnb['latitude'] = airbnb['latitude'].astype(float)

## LONGITUDE
airbnb['longitude'] = [re.sub('[^0-9.-]','',str(x)) for x in airbnb['longitude']]
airbnb['longitude'] = airbnb['longitude'].astype(float)

# %%
airbnb.head(30)
# Out:
#        id                                               name  host   id  \
# 0    2539                 Clean & quiet apt home by the park       2787
# 1    2595                              Skylit Midtown Castle       2845
# 2    3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3    3831                    Cozy Entire Floor of Brownstone       4869
# 4    5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5    5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6    5121                                    BlissArtsSpace!       7356
# 7    5203                 Cozy Clean Guest Room - Family Apt       7490
# 8    5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 9    5295                   Beautiful 1br on Upper West Side       7702
# 10   5441                    Central Manhattan/near Broadway       7989
# 11   6090                      West Village Nest - Superhost      11975
# 12   6848                   Only 2 stops to Manhattan studio      15991
# 13   7097                  Perfect for Your Parents + Garden      17571
# 14   7322                                    Chelsea Perfect      18946
# 15   7726    Hip Historic Brownstone Apartment with Backyard      20950
# 16   7750                  Huge 2 BR Upper East  Cental Park      17985
# 17   7801                   Sweet and Spacious Brooklyn Loft      21207
# 18   8024                     CBG CtyBGd HelpsHaiti rm#1:1-4      22486
# 19   8025                           CBG Helps Haiti Room#2.5      22486
# 20   8110                              CBG Helps Haiti Rm #2      22486
# 21   8700  Magnifique Suite au N de Manhattan - vue Cloitres      26394
# 22   9357                               Midtown Pied-a-terre      30193
# 23   9657                   Modern 1 BR / NYC / EAST VILLAGE      21904
# 24   9704                Spacious 1 bedroom in luxe building      32045
# 25   9782                  Loft in Williamsburg Area w/ Roof      32169
# 26   9783                                back room/bunk beds      32294
# 27  11452                        Clean and Quiet in Brooklyn       7355
# 28  11708                          Cute apt in artist's home      44145
# 29  11943                          Country space in the city      45445
#
#          [host_name]     neighbourhood group  \
# 0               John  Brooklyn - **Borough**
# 1           Jennifer               Manhattan
# 2          Elisabeth               Manhattan
# 3        LisaRoxanne                Brooklyn
# 4              Laura               Manhattan
# 5              Chris               Manhattan
# 6              Garon                Brooklyn
# 7          MaryEllen               Manhattan
# 8                Ben               Manhattan
# 9               Lena               Manhattan
# 10              Kate               Manhattan
# 11             Alina               Manhattan
# 12     Allen & Irina                Brooklyn
# 13              Jane                Brooklyn
# 14            "Doti"               Manhattan
# 15  Adam And Charity                Brooklyn
# 16              Sing               Manhattan
# 17             Chaya                Brooklyn
# 18             Lisel                Brooklyn
# 19             Lisel                Brooklyn
# 20             Lisel                Brooklyn
# 21   Claude & Sophie               Manhattan
# 22             Tommi               Manhattan
# 23              Dana               Manhattan
# 24              Teri               Manhattan
# 25            Andrea                Brooklyn
# 26   Ssameer Or Trip               Manhattan
# 27                Vt                Brooklyn
# 28            Tyrome                Brooklyn
# 29           Harriet                Brooklyn
#
#                                         neighbourhood  latitude  longitude  \
# 0   KensingtonBrooklyn - **Borough**-Brooklyn - **...  40.64749  -73.97237
# 1                                             Midtown  40.75362  -73.98377
# 2                                              Harlem  40.80902  -73.94190
# 3                                        Clinton Hill  40.68514  -73.95976
# 4                                         East Harlem  40.79851  -73.94399
# 5                                         Murray Hill  40.74767  -73.97500
# 6                                  Bedford-Stuyvesant  40.68688  -73.95596
# 7                                     Upper West Side  40.80178  -73.96723
# 8                                           Chinatown  40.71344  -73.99037
# 9                                     Upper West Side  40.80316  -73.96545
# 10                                     Hell's Kitchen  40.76076  -73.98867
# 11                                       West Village  40.73530  -74.00525
# 12                                       Williamsburg  40.70837  -73.95352
# 13                                        Fort Greene  40.69169  -73.97185
# 14                                            Chelsea  40.74192  -73.99501
# 15                                      Crown Heights  40.67592  -73.94694
# 16                                        East Harlem  40.79685  -73.94872
# 17                                       Williamsburg  40.71842  -73.95718
# 18                                         Park Slope  40.68069  -73.97706
# 19                                         Park Slope  40.67989  -73.97798
# 20                                         Park Slope  40.68001  -73.97865
# 21                                             Inwood  40.86754  -73.92639
# 22                                     Hell's Kitchen  40.76715  -73.98533
# 23                                       East Village  40.72920  -73.98542
# 24                                             Harlem  40.81305  -73.95466
# 25                                         Greenpoint  40.72219  -73.93762
# 26                                             Harlem  40.82130  -73.95318
# 27                                 Bedford-Stuyvesant  40.68876  -73.94312
# 28                                           Bushwick  40.70186  -73.92745
# 29                                           Flatbush  40.63702  -73.96327
#
#       room and type  minimum nights  number of reviews (total)  \
# 0      Private room               1                          9
# 1   Entire home/apt               1                         45
# 2      Private room               3                          0
# 3   Entire home/apt               1                        270
# 4   Entire home/apt              10                          9
# 5   Entire home/apt               3                         74
# 6      Private room              45                         49
# 7      Private room               2                        118
# 8   Entire home/apt               1                        160
# 9   Entire home/apt               5                         53
# 10     Private room               2                        188
# 11  Entire home/apt              90                         27
# 12  Entire home/apt               2                        148
# 13  Entire home/apt               2                        198
# 14     Private room               1                        260
# 15  Entire home/apt               3                         53
# 16  Entire home/apt               7                          0
# 17  Entire home/apt               3                          9
# 18     Private room               2                        130
# 19     Private room               1                         39
# 20     Private room               2                         71
# 21     Private room               4                          0
# 22  Entire home/apt              10                         58
# 23  Entire home/apt              14                         29
# 24     Private room               2                         88
# 25     Private room               4                        197
# 26     Private room               3                        273
# 27     Private room              60                          0
# 28  Entire home/apt               2                        231
# 29     Private room               1                          0
#
#    last review (date)  reviews per month        floor  noise.dB.  price
# 0          2018-10-19               0.21  First Floor  69.056465    149
# 1          2019-05-21               0.38  First Floor  56.054278    225
# 2                 NaN               0.00  First Floor  56.054278    150
# 3          2019-07-05               4.64  First Floor  69.056465     89
# 4          2018-11-19               0.10  First Floor  56.054278     80
# 5          2019-06-22               0.59            1  56.054278    200
# 6          2017-10-05               0.40  First Floor  69.056465     60
# 7          2017-07-21               0.99  First Floor  56.054278     79
# 8          2019-06-09               1.33  First Floor  56.054278    150
# 9          2019-06-22               0.43  First Floor  56.054278    135
# 10         2019-06-23               1.50  First Floor  56.054278     85
# 11         2018-10-31               0.22  First Floor  56.054278    120
# 12         2019-06-29               1.20  First Floor  69.056465    140
# 13         2019-06-28               1.72  First Floor  69.056465    215
# 14         2019-07-01               2.12  First Floor  56.054278    140
# 15         2019-06-22               4.44  First Floor  69.056465     99
# 16                NaN               0.00  First Floor  56.054278    190
# 17         2011-12-28               0.07  First Floor  69.056465    299
# 18         2019-07-01               1.09  First Floor  69.056465    130
# 19         2019-01-01               0.37  First Floor  69.056465     80
# 20         2019-07-02               0.61  First Floor  69.056465    110
# 21                NaN               0.00  First Floor  56.054278     80
# 22         2017-08-13               0.49  First Floor  56.054278    150
# 23         2019-04-19               0.24  First Floor  56.054278    180
# 24         2019-06-14               1.42  First Floor  56.054278     52
# 25         2019-06-15               1.65  First Floor  69.056465     55
# 26         2019-07-01               2.37  First Floor  56.054278     50
# 27                NaN               0.00  First Floor  69.056465     35
# 28         2019-06-22               1.96            1  69.056465     85
# 29                NaN               0.00  First Floor  69.056465    150

# %% [markdown]
# ## Categorical Columns

# %%
#airbnb['floor'].unique()

# %%
## FLOORS
airbnb['floor'] = [re.sub('Lower Level','0',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('First Floor|1st-floor','1',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Second Floor','2',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Third Floor','3',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Fourth Floor','4',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Fifth Floor|5th floor|5th Floor','5',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Sixth Floor','6',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Seventh Floor','7',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Eighth Floor','8',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Ninth Floor','9',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Tenth Floor','10',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Eleventh Floor','11',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Thirteenth Floor','13',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Sixteenth Floor','16',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Seventeenth Floor','17',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Twentieth Floor','20',str(x)) for x in airbnb['floor']]
airbnb['floor'] = [re.sub('Hundreth Floor','100',str(x)) for x in airbnb['floor']]

airbnb['floor'] = airbnb['floor'].astype(int)

# %%
#airbnb['room and type'].unique()

# %%
## Room Type
airbnb['room and type'] = [re.sub('Room Type Private|Privatè-Room','Private room',str(x)) for x in airbnb['room and type']]

# %%
#airbnb['neighbourhood'].unique()

# %%
#airbnb['neighbourhood group'].unique()

# %%
##Neighbourhood Groups
airbnb['neighbourhood group'] = [re.sub('Brooklyn - \*\*Borough\*\*|Brooklyn Borough|brklyn','Brooklyn',str(x)) for x in airbnb['neighbourhood group']]
airbnb['neighbourhood group'] = [re.sub('broxn|  bronx_borugh|B-r-0-n-x|Bronx   ','Bronx',str(x)) for x in airbnb['neighbourhood group']]

# %%
##Neighbourhoods
airbnb['neighbourhood'] = [re.sub('Brooklyn - \*\*Borough\*\*-Brooklyn - \*\*Borough\*\*|Brooklyn-Brooklyn|Brooklyn Borough-Brooklyn Borough|brklyn-brklyn','',str(x)) for x in airbnb['neighbourhood']]
airbnb['neighbourhood'] = [re.sub('Manhattan-Manhattan','',str(x)) for x in airbnb['neighbourhood']]
airbnb['neighbourhood'] = [re.sub('Bronx-Bronx|broxn   -broxn   ','',str(x)) for x in airbnb['neighbourhood']]
airbnb['neighbourhood'] = [re.sub('Queens-Queens','',str(x)) for x in airbnb['neighbourhood']]
airbnb['neighbourhood'] = [re.sub('Staten Island-Staten Island|, Staten Island','',str(x)) for x in airbnb['neighbourhood']]
airbnb['neighbourhood'] = airbnb['neighbourhood'].replace('nan',np.nan,regex=True)

# %% [markdown]
# ## Date Column

# %%
## Last Review
airbnb['last review (date)'] = [re.sub('nan','3000-01-01',str(x)) for x in airbnb['last review (date)']]
airbnb['last review (date)']=airbnb['last review (date)'].apply(lambda x:datetime.strptime(x,"%Y-%m-%d"))
airbnb['last review (date)']=airbnb['last review (date)'].apply(lambda x:datetime.strftime(x,"%Y-%m-%d"))
airbnb = airbnb.replace('3000-01-01',np.nan,regex=True)

# %%
airbnb.head(30)
# Out:
#        id                                               name  host   id  \
# 0    2539                 Clean & quiet apt home by the park       2787
# 1    2595                              Skylit Midtown Castle       2845
# 2    3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3    3831                    Cozy Entire Floor of Brownstone       4869
# 4    5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5    5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6    5121                                    BlissArtsSpace!       7356
# 7    5203                 Cozy Clean Guest Room - Family Apt       7490
# 8    5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 9    5295                   Beautiful 1br on Upper West Side       7702
# 10   5441                    Central Manhattan/near Broadway       7989
# 11   6090                      West Village Nest - Superhost      11975
# 12   6848                   Only 2 stops to Manhattan studio      15991
# 13   7097                  Perfect for Your Parents + Garden      17571
# 14   7322                                    Chelsea Perfect      18946
# 15   7726    Hip Historic Brownstone Apartment with Backyard      20950
# 16   7750                  Huge 2 BR Upper East  Cental Park      17985
# 17   7801                   Sweet and Spacious Brooklyn Loft      21207
# 18   8024                     CBG CtyBGd HelpsHaiti rm#1:1-4      22486
# 19   8025                           CBG Helps Haiti Room#2.5      22486
# 20   8110                              CBG Helps Haiti Rm #2      22486
# 21   8700  Magnifique Suite au N de Manhattan - vue Cloitres      26394
# 22   9357                               Midtown Pied-a-terre      30193
# 23   9657                   Modern 1 BR / NYC / EAST VILLAGE      21904
# 24   9704                Spacious 1 bedroom in luxe building      32045
# 25   9782                  Loft in Williamsburg Area w/ Roof      32169
# 26   9783                                back room/bunk beds      32294
# 27  11452                        Clean and Quiet in Brooklyn       7355
# 28  11708                          Cute apt in artist's home      44145
# 29  11943                          Country space in the city      45445
#
#          [host_name] neighbourhood group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# 5              Chris           Manhattan         Murray Hill  40.74767
# 6              Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 7          MaryEllen           Manhattan     Upper West Side  40.80178
# 8                Ben           Manhattan           Chinatown  40.71344
# 9               Lena           Manhattan     Upper West Side  40.80316
# 10              Kate           Manhattan      Hell's Kitchen  40.76076
# 11             Alina           Manhattan        West Village  40.73530
# 12     Allen & Irina            Brooklyn        Williamsburg  40.70837
# 13              Jane            Brooklyn         Fort Greene  40.69169
# 14            "Doti"           Manhattan             Chelsea  40.74192
# 15  Adam And Charity            Brooklyn       Crown Heights  40.67592
# 16              Sing           Manhattan         East Harlem  40.79685
# 17             Chaya            Brooklyn        Williamsburg  40.71842
# 18             Lisel            Brooklyn          Park Slope  40.68069
# 19             Lisel            Brooklyn          Park Slope  40.67989
# 20             Lisel            Brooklyn          Park Slope  40.68001
# 21   Claude & Sophie           Manhattan              Inwood  40.86754
# 22             Tommi           Manhattan      Hell's Kitchen  40.76715
# 23              Dana           Manhattan        East Village  40.72920
# 24              Teri           Manhattan              Harlem  40.81305
# 25            Andrea            Brooklyn          Greenpoint  40.72219
# 26   Ssameer Or Trip           Manhattan              Harlem  40.82130
# 27                Vt            Brooklyn  Bedford-Stuyvesant  40.68876
# 28            Tyrome            Brooklyn            Bushwick  40.70186
# 29           Harriet            Brooklyn            Flatbush  40.63702
#
#     longitude    room and type  minimum nights  number of reviews (total)  \
# 0   -73.97237     Private room               1                          9
# 1   -73.98377  Entire home/apt               1                         45
# 2   -73.94190     Private room               3                          0
# 3   -73.95976  Entire home/apt               1                        270
# 4   -73.94399  Entire home/apt              10                          9
# 5   -73.97500  Entire home/apt               3                         74
# 6   -73.95596     Private room              45                         49
# 7   -73.96723     Private room               2                        118
# 8   -73.99037  Entire home/apt               1                        160
# 9   -73.96545  Entire home/apt               5                         53
# 10  -73.98867     Private room               2                        188
# 11  -74.00525  Entire home/apt              90                         27
# 12  -73.95352  Entire home/apt               2                        148
# 13  -73.97185  Entire home/apt               2                        198
# 14  -73.99501     Private room               1                        260
# 15  -73.94694  Entire home/apt               3                         53
# 16  -73.94872  Entire home/apt               7                          0
# 17  -73.95718  Entire home/apt               3                          9
# 18  -73.97706     Private room               2                        130
# 19  -73.97798     Private room               1                         39
# 20  -73.97865     Private room               2                         71
# 21  -73.92639     Private room               4                          0
# 22  -73.98533  Entire home/apt              10                         58
# 23  -73.98542  Entire home/apt              14                         29
# 24  -73.95466     Private room               2                         88
# 25  -73.93762     Private room               4                        197
# 26  -73.95318     Private room               3                        273
# 27  -73.94312     Private room              60                          0
# 28  -73.92745  Entire home/apt               2                        231
# 29  -73.96327     Private room               1                          0
#
#    last review (date)  reviews per month  floor  noise.dB.  price
# 0          2018-10-19               0.21      1  69.056465    149
# 1          2019-05-21               0.38      1  56.054278    225
# 2                 NaN               0.00      1  56.054278    150
# 3          2019-07-05               4.64      1  69.056465     89
# 4          2018-11-19               0.10      1  56.054278     80
# 5          2019-06-22               0.59      1  56.054278    200
# 6          2017-10-05               0.40      1  69.056465     60
# 7          2017-07-21               0.99      1  56.054278     79
# 8          2019-06-09               1.33      1  56.054278    150
# 9          2019-06-22               0.43      1  56.054278    135
# 10         2019-06-23               1.50      1  56.054278     85
# 11         2018-10-31               0.22      1  56.054278    120
# 12         2019-06-29               1.20      1  69.056465    140
# 13         2019-06-28               1.72      1  69.056465    215
# 14         2019-07-01               2.12      1  56.054278    140
# 15         2019-06-22               4.44      1  69.056465     99
# 16                NaN               0.00      1  56.054278    190
# 17         2011-12-28               0.07      1  69.056465    299
# 18         2019-07-01               1.09      1  69.056465    130
# 19         2019-01-01               0.37      1  69.056465     80
# 20         2019-07-02               0.61      1  69.056465    110
# 21                NaN               0.00      1  56.054278     80
# 22         2017-08-13               0.49      1  56.054278    150
# 23         2019-04-19               0.24      1  56.054278    180
# 24         2019-06-14               1.42      1  56.054278     52
# 25         2019-06-15               1.65      1  69.056465     55
# 26         2019-07-01               2.37      1  56.054278     50
# 27                NaN               0.00      1  69.056465     35
# 28         2019-06-22               1.96      1  69.056465     85
# 29                NaN               0.00      1  69.056465    150
